# %% [markdown]
# <a href="https://colab.research.google.com/github/sd8012645/Capstone_project/blob/main/capstoen_step2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# !pip install nbformat

import nbformat as nbf
from pathlib import Path



#from google.colab import files
up=files.upload()
print(up.keys())
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !pip install -q kaggle
# 1. Make data folder
# !mkdir -p data

# 2. Download the Kaggle dataset into ./data
# !kaggle datasets download -d marcelwiechmann/enron-spam-data -p data
# 3. Unzip the downloaded file
# !unzip -o data/enron-spam-data.zip -d data
# Out:
# ...
#      <input type="file" id="files-9061ff11-14d4-4241-a0b7-c762372a6646" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9061ff11-14d4-4241-a0b7-c762372a6646">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 4. List contents of data folder
# !ls data
# Out:
# build_data_file.py    enron_spam_data.csv  README.md
# emails.csv	      enron-spam-data.zip  spam-email-dataset.zip
# email_spam_train.csv  LICENSE

# %%
import pandas as pd

df_1 = pd.read_csv("data/enron_spam_data.csv")  # <- use the real name you saw from !ls
df_1.head(1000)
#
# Out:
#      Unnamed: 0                       Subject  \
# 0             0  christmas tree farm pictures
# 1             1      vastar resources , inc .
# 2             2  calpine daily gas nomination
# 3             3                    re : issue
# 4             4     meter 7268 nov allocation
# ..          ...                           ...
# 995         995       resume - robert goerner
# 996         996            resume - anna cola
# 997         997         resume - alex argueta
# 998         998          resume - liz bellamy
# 999         999         resume - gloria smith
#
#                                                Message Spam/Ham        Date
# 0                                                  NaN      ham  1999-12-10
# 1    gary , production from the high island larger ...      ham  1999-12-13
# 2               - calpine daily gas nomination 1 . doc      ham  1999-12-14
# 3    fyi - see note below - already done .\nstella\...      ham  1999-12-14
# ...

# %%
# !kaggle datasets download -d jackksoncsie/spam-email-dataset -p data
# !unzip -o data/spam-email-dataset.zip -d data
# !ls data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jackksoncsie/spam-email-dataset
# License(s): GNU Lesser General Public License 3.0
# spam-email-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  data/spam-email-dataset.zip
#   inflating: data/emails.csv
# build_data_file.py    enron_spam_data.csv  README.md
# emails.csv	      enron-spam-data.zip  spam-email-dataset.zip
# email_spam_train.csv  LICENSE

# %%
df_2 = pd.read_csv("data/emails.csv")  # <- use the real name you saw from !ls
df_2.head(1000)
# Out:
#                                                   text  spam
# 0    Subject: naturally irresistible your corporate...     1
# 1    Subject: the stock trading gunslinger  fanny i...     1
# 2    Subject: unbelievable new homes made easy  im ...     1
# 3    Subject: 4 color printing special  request add...     1
# 4    Subject: do not have money , get software cds ...     1
# ..                                                 ...   ...
# 995  Subject: save your money by getting an oem sof...     1
# 996  Subject: software for system builders , resell...     1
# 997  Subject: fantastic investors info  maisonette ...     1
# 998  Subject: save your money buy getting this thin...     1
# 999  Subject: 70 percent off your life insurance ge...     1
#
# [1000 rows x 2 columns]

# %%
# !pip install -q datasets huggingface_hub
from huggingface_hub import notebook_login
notebook_login()  # will ask you to paste your hf_... token

# %%
from datasets import load_dataset

ds = load_dataset("UniqueData/email-spam-classification")
print(ds)           # see the splits (train/test/etc)
ds_train = ds["train"]
ds_train[:3]        # first 3 rows
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'text', 'type'],
#         num_rows: 84
#     })
# })
# {'title': ['?? the secrets to SUCCESS',
#   '?? You Earned 500 GCLoot Points',
#   '?? Your GitHub launch code'],
#  'text': ["Hi James,\n\nHave you claim your complimentary gift yet?\n\nI've compiled in here a special astrology gift that predicts everything about you in the future?\n\nThis is your enabler to take the correct actions now.\n\n>> Click here to claim your copy now >>\n\nClaim yours now, and thank me later.\n\n\nLove,\nHeather",
#   '\nalt_text\nCongratulations, you just earned\n500\n\n\nYou completed the following offer:\n\nView Points History\nTo stop recieving notifications when you earn points, please visit your profile and click "Preferences" to change your setting.\n\nRoom 1203, 12th Floor, Tower 3\n\nChina Hong Kong City, 33 Canton Road\n\nTsim Sha Tsui, Kowloon, Hong Kong\n\nUnsubscribe',
# ...

# %%
# !ls data
# Out:
# build_data_file.py    enron_spam_data.csv  README.md
# emails.csv	      enron-spam-data.zip  spam-email-dataset.zip
# email_spam_train.csv  LICENSE

# %%
os.makedirs("data", exist_ok=True)

# 3. Save each split (train/test/validation, etc.) as a CSV in data/
for split_name, split_ds in ds.items():
    df = split_ds.to_pandas()
    csv_path = f"data/email_spam_{split_name}.csv"
    df.to_csv(csv_path, index=False)
    print("Saved:", csv_path)
# Out:
# Saved: data/email_spam_train.csv

# %%
# !ls data
# Out:
# build_data_file.py    enron_spam_data.csv  README.md
# emails.csv	      enron-spam-data.zip  spam-email-dataset.zip
# email_spam_train.csv  LICENSE
